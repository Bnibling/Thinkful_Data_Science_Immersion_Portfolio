# %% [markdown]
# <a href="https://colab.research.google.com/github/Bnibling/Thinkful_Data_Science_Immersion_Portfolio/blob/main/DL_Challenge_Fashion_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning Challenge - ANN models of [fashion MNIST](https://github.com/zalandoresearch/fashion-mnist)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, RMSprop, Adam, Adagrad

from sklearn.metrics import confusion_matrix
import itertools

# %% [markdown]
# 1. Preprocess your data so that you can feed it into ANN models.
# 2. Split your data into training and test sets.

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

input_dim = 784 #28x28
output_dim = num_classes = 10 #number of classes 0-9
batch_size = 128
num_epochs = 20

X_train = X_train.reshape(60000,784).astype('float32')
X_test = X_test.reshape(10000, input_dim).astype('float32')
X_train /= 255
X_test /= 255

y_train = to_categorical(y_train, num_classes)
y_test= to_categorical(y_test, num_classes)

# %% [markdown]
# 3. Try different ANN models and train them on your training set.

# %%
def build_3_layer_model(
    neuron_list=np.array([512, 256]),
    neuron_multiplier = 1,
    opt='adam', 
    activation='relu', 
    loss='categorical_crossentropy',
    batch_size=128,
    ):
  model = Sequential()

  model.add(Dense(neuron_list[0]*neuron_multiplier, input_dim=X_train.shape[1], activation=activation))
  model.add(Dense(neuron_list[1]*neuron_multiplier, activation=activation))
  model.add(Dense(output_dim, activation='softmax'))
  model.compile(optimizer=opt, loss=loss, 
              metrics=['accuracy'])
  
  print(f'{neuron_multiplier}_{activation}_{batch_size}_{opt}_3_model')
  return model

# %%
def build_4_layer_model(
    neuron_list=np.array([512, 256, 128]),
    neuron_multiplier = 1,
    opt='adam', 
    activation='relu', 
    loss='categorical_crossentropy',
    batch_size=128,
    ):
  model = Sequential()

  model.add(Dense(neuron_list[0]*neuron_multiplier, input_dim=X_train.shape[1], activation=activation))
  model.add(Dense(neuron_list[1]*neuron_multiplier, activation=activation))
  model.add(Dense(neuron_list[2]*neuron_multiplier, activation=activation))
  model.add(Dense(output_dim, activation='softmax'))
  model.compile(optimizer=opt, loss=loss, 
              metrics=['accuracy'])
  
  print(f'{neuron_multiplier}_{activation}_{batch_size}_{opt}_4_model')
  return model

# %%
def build_5_layer_model(
    neuron_list=np.array([512, 256, 128, 64]),
    neuron_multiplier = 1,
    opt='adam', 
    activation='relu', 
    loss='categorical_crossentropy',
    batch_size=128,
    ):
  model = Sequential()

  model.add(Dense(neuron_list[0]*neuron_multiplier, input_dim=X_train.shape[1], activation=activation))
  model.add(Dense(neuron_list[1]*neuron_multiplier, activation=activation))
  model.add(Dense(neuron_list[2]*neuron_multiplier, activation=activation))
  model.add(Dense(neuron_list[3]*neuron_multiplier, activation=activation))
  model.add(Dense(output_dim, activation='softmax'))
  model.compile(optimizer=opt, loss=loss, 
              metrics=['accuracy'])
  
  print(f'{neuron_multiplier}_{activation}_{batch_size}_{opt}_5_model')
  return model

# %%
neuron_multipliers = [0.5, 1, 2]
activations = ['relu', 'tanh']
batch_sizes = [64, 128, 256, X_train.shape[0]]
optimizers = ['sgd', 'adam']

# %%
ANN_fashion_models = {f'{neuron_multiplier}_{activation}_{batch_size}_{opt}_{i+3}_model':build_model(
              neuron_multiplier=neuron_multiplier, 
              batch_size=batch_size,
              opt=opt,
              activation=activation,
              loss='categorical_crossentropy',  
              ).fit(X_train, y_train, validation_data=(X_test, y_test),
              batch_size=batch_size, epochs=num_epochs, verbose=0) 
              for opt in optimizers 
              for batch_size in batch_sizes 
              for activation in activations 
              for neuron_multiplier in neuron_multipliers
              for i, build_model in enumerate([build_3_layer_model, build_4_layer_model, build_5_layer_model])}
# Out:
# 0.5_relu_64_sgd_3_model
# 0.5_relu_64_sgd_4_model
# 0.5_relu_64_sgd_5_model
# 1_relu_64_sgd_3_model
# 1_relu_64_sgd_4_model
# 1_relu_64_sgd_5_model
# 2_relu_64_sgd_3_model
# 2_relu_64_sgd_4_model
# 2_relu_64_sgd_5_model
# 0.5_tanh_64_sgd_3_model
# 0.5_tanh_64_sgd_4_model
# 0.5_tanh_64_sgd_5_model
# 1_tanh_64_sgd_3_model
# 1_tanh_64_sgd_4_model
# 1_tanh_64_sgd_5_model
# 2_tanh_64_sgd_3_model
# 2_tanh_64_sgd_4_model
# 2_tanh_64_sgd_5_model
# 0.5_relu_128_sgd_3_model
# 0.5_relu_128_sgd_4_model
# 0.5_relu_128_sgd_5_model
# 1_relu_128_sgd_3_model
# 1_relu_128_sgd_4_model
# 1_relu_128_sgd_5_model
# 2_relu_128_sgd_3_model
# 2_relu_128_sgd_4_model
# 2_relu_128_sgd_5_model
# 0.5_tanh_128_sgd_3_model
# 0.5_tanh_128_sgd_4_model
# 0.5_tanh_128_sgd_5_model
# 1_tanh_128_sgd_3_model
# 1_tanh_128_sgd_4_model
# 1_tanh_128_sgd_5_model
# 2_tanh_128_sgd_3_model
# 2_tanh_128_sgd_4_model
# 2_tanh_128_sgd_5_model
# 0.5_relu_256_sgd_3_model
# 0.5_relu_256_sgd_4_model
# 0.5_relu_256_sgd_5_model
# 1_relu_256_sgd_3_model
# 1_relu_256_sgd_4_model
# 1_relu_256_sgd_5_model
# 2_relu_256_sgd_3_model
# 2_relu_256_sgd_4_model
# 2_relu_256_sgd_5_model
# 0.5_tanh_256_sgd_3_model
# 0.5_tanh_256_sgd_4_model
# 0.5_tanh_256_sgd_5_model
# 1_tanh_256_sgd_3_model
# 1_tanh_256_sgd_4_model
# 1_tanh_256_sgd_5_model
# 2_tanh_256_sgd_3_model
# 2_tanh_256_sgd_4_model
# 2_tanh_256_sgd_5_model
# 0.5_relu_60000_sgd_3_model
# 0.5_relu_60000_sgd_4_model
# 0.5_relu_60000_sgd_5_model
# 1_relu_60000_sgd_3_model
# 1_relu_60000_sgd_4_model
# 1_relu_60000_sgd_5_model
# 2_relu_60000_sgd_3_model
# 2_relu_60000_sgd_4_model
# 2_relu_60000_sgd_5_model
# 0.5_tanh_60000_sgd_3_model
# 0.5_tanh_60000_sgd_4_model
# 0.5_tanh_60000_sgd_5_model
# 1_tanh_60000_sgd_3_model
# 1_tanh_60000_sgd_4_model
# 1_tanh_60000_sgd_5_model
# 2_tanh_60000_sgd_3_model
# 2_tanh_60000_sgd_4_model
# 2_tanh_60000_sgd_5_model
# 0.5_relu_64_adam_3_model
# 0.5_relu_64_adam_4_model
# 0.5_relu_64_adam_5_model
# 1_relu_64_adam_3_model
# 1_relu_64_adam_4_model
# 1_relu_64_adam_5_model
# 2_relu_64_adam_3_model
# 2_relu_64_adam_4_model
# 2_relu_64_adam_5_model
# 0.5_tanh_64_adam_3_model
# 0.5_tanh_64_adam_4_model
# 0.5_tanh_64_adam_5_model
# 1_tanh_64_adam_3_model
# 1_tanh_64_adam_4_model
# 1_tanh_64_adam_5_model
# 2_tanh_64_adam_3_model
# 2_tanh_64_adam_4_model
# 2_tanh_64_adam_5_model
# 0.5_relu_128_adam_3_model
# 0.5_relu_128_adam_4_model
# 0.5_relu_128_adam_5_model
# 1_relu_128_adam_3_model
# 1_relu_128_adam_4_model
# 1_relu_128_adam_5_model
# 2_relu_128_adam_3_model
# 2_relu_128_adam_4_model
# 2_relu_128_adam_5_model
# 0.5_tanh_128_adam_3_model
# 0.5_tanh_128_adam_4_model
# 0.5_tanh_128_adam_5_model
# 1_tanh_128_adam_3_model
# 1_tanh_128_adam_4_model
# 1_tanh_128_adam_5_model
# 2_tanh_128_adam_3_model
# 2_tanh_128_adam_4_model
# 2_tanh_128_adam_5_model
# 0.5_relu_256_adam_3_model
# 0.5_relu_256_adam_4_model
# 0.5_relu_256_adam_5_model
# 1_relu_256_adam_3_model
# 1_relu_256_adam_4_model
# 1_relu_256_adam_5_model
# 2_relu_256_adam_3_model
# 2_relu_256_adam_4_model
# 2_relu_256_adam_5_model
# 0.5_tanh_256_adam_3_model
# 0.5_tanh_256_adam_4_model
# 0.5_tanh_256_adam_5_model
# 1_tanh_256_adam_3_model
# 1_tanh_256_adam_4_model
# 1_tanh_256_adam_5_model
# 2_tanh_256_adam_3_model
# 2_tanh_256_adam_4_model
# 2_tanh_256_adam_5_model
# 0.5_relu_60000_adam_3_model
# 0.5_relu_60000_adam_4_model
# 0.5_relu_60000_adam_5_model
# 1_relu_60000_adam_3_model
# 1_relu_60000_adam_4_model
# 1_relu_60000_adam_5_model
# 2_relu_60000_adam_3_model
# 2_relu_60000_adam_4_model
# 2_relu_60000_adam_5_model
# 0.5_tanh_60000_adam_3_model
# 0.5_tanh_60000_adam_4_model
# 0.5_tanh_60000_adam_5_model
# 1_tanh_60000_adam_3_model
# 1_tanh_60000_adam_4_model
# 1_tanh_60000_adam_5_model
# 2_tanh_60000_adam_3_model
# 2_tanh_60000_adam_4_model
# 2_tanh_60000_adam_5_model

# %% [markdown]
# 4. Compare your models' training scores and interpret your results.
# 5. Evaluate how your models perform on your test set. Compare the results of your models.

# %%
model_scores = {model_name:{metric:score[-1] for metric, score in model.history.items()} for model_name, model in ANN_fashion_models.items()}
model_scores

# %%
scores_df = pd.DataFrame.from_dict(model_scores, orient='index')

# %%
scores_df.sort_values(by=['accuracy', 'loss'], ascending=False).head(10).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_987c12b0_5112_11eb_b6a5_0242ac1c0002row0_col0{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row0_col1,#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row2_col2,#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row3_col3,#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row9_col0{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row0_col2{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row0_col3{
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row1_col0{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row1_col1{
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row1_col2{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row1_col3{
#             background-color:  #4897c4;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row2_col0,#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row3_col0,#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row5_col3,#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row9_col1,#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row9_col2{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row2_col1{
#             background-color:  #1b7eb7;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row2_col3{
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row3_col1{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row3_col2{
#             background-color:  #cacee5;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row4_col0{
#             background-color:  #2786bb;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row4_col1,#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row8_col0{
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row4_col2{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row4_col3{
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row5_col0{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row5_col1{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row5_col2{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row6_col0{
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row6_col1{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row6_col2{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row6_col3{
#             background-color:  #167bb6;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row7_col0{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row7_col1{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row7_col2,#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row8_col1{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row7_col3{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row8_col2{
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row8_col3{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_987c12b0_5112_11eb_b6a5_0242ac1c0002row9_col3{
#             background-color:  #589ec8;
#             color:  #000000;
#         }</style><table id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >loss</th>        <th class="col_heading level0 col1" >accuracy</th>        <th class="col_heading level0 col2" >val_loss</th>        <th class="col_heading level0 col3" >val_accuracy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002level0_row0" class="row_heading level0 row0" >2_relu_256_adam_3_model</th>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row0_col0" class="data row0 col0" >0.142256</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row0_col1" class="data row0 col1" >0.946133</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row0_col2" class="data row0 col2" >0.350847</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row0_col3" class="data row0 col3" >0.895800</td>
#             </tr>
#             <tr>
#                         <th id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002level0_row1" class="row_heading level0 row1" >2_relu_256_adam_4_model</th>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row1_col0" class="data row1 col0" >0.141142</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row1_col1" class="data row1 col1" >0.946017</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row1_col2" class="data row1 col2" >0.359076</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row1_col3" class="data row1 col3" >0.892200</td>
#             </tr>
#             <tr>
#                         <th id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002level0_row2" class="row_heading level0 row2" >2_relu_64_adam_3_model</th>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row2_col0" class="data row2 col0" >0.139447</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row2_col1" class="data row2 col1" >0.945417</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row2_col2" class="data row2 col2" >0.406653</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row2_col3" class="data row2 col3" >0.895300</td>
#             </tr>
#             <tr>
#                         <th id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002level0_row3" class="row_heading level0 row3" >2_relu_128_adam_3_model</th>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row3_col0" class="data row3 col0" >0.139479</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row3_col1" class="data row3 col1" >0.945033</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row3_col2" class="data row3 col2" >0.345708</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row3_col3" class="data row3 col3" >0.896100</td>
#             </tr>
#             <tr>
#                         <th id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002level0_row4" class="row_heading level0 row4" >2_tanh_256_adam_4_model</th>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row4_col0" class="data row4 col0" >0.147131</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row4_col1" class="data row4 col1" >0.945000</td>
#                         <td id="T_987c12b0_5112_11eb_b6a5_0242ac1c0002row4_col2" class="data row4 col2" >0.328712</td>
#                         <td id="T_987c12b0_5112_

# %% [markdown]
# From the table above, we can see that all of the top performing models have comparable scores across all four metrics. All of the top 10 models were trained using the `adam` optimizer and most have a neuron multiplier of 2 and utilize `relu` activation.

# %%
scores_df.sort_values(by=['val_accuracy', 'val_loss'], ascending=False).head(10).style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row0_col0{
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row0_col1,#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row3_col2{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row0_col2{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row0_col3,#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row5_col2,#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row6_col1,#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row8_col0{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row1_col0{
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row1_col1{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row1_col2,#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row5_col3{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row1_col3{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row2_col0{
#             background-color:  #3790c0;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row2_col1{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row2_col2{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row2_col3{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row3_col0,#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row4_col2,#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row8_col1,#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row9_col0,#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row9_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row3_col1{
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row3_col3{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row4_col0{
#             background-color:  #549cc7;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row4_col1{
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row4_col3{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row5_col0{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row5_col1{
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row6_col0{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row6_col2{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row6_col3{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row7_col0{
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row7_col1{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row7_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row7_col3{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row8_col2{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row8_col3{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row9_col1{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row9_col2{
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }</style><table id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >loss</th>        <th class="col_heading level0 col1" >accuracy</th>        <th class="col_heading level0 col2" >val_loss</th>        <th class="col_heading level0 col3" >val_accuracy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002level0_row0" class="row_heading level0 row0" >2_relu_64_adam_5_model</th>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row0_col0" class="data row0 col0" >0.159214</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row0_col1" class="data row0 col1" >0.938933</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row0_col2" class="data row0 col2" >0.365093</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row0_col3" class="data row0 col3" >0.898700</td>
#             </tr>
#             <tr>
#                         <th id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002level0_row1" class="row_heading level0 row1" >0.5_relu_64_adam_3_model</th>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row1_col0" class="data row1 col0" >0.155123</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row1_col1" class="data row1 col1" >0.940217</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row1_col2" class="data row1 col2" >0.351890</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row1_col3" class="data row1 col3" >0.896500</td>
#             </tr>
#             <tr>
#                         <th id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002level0_row2" class="row_heading level0 row2" >2_relu_128_adam_5_model</th>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row2_col0" class="data row2 col0" >0.152830</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row2_col1" class="data row2 col1" >0.941167</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row2_col2" class="data row2 col2" >0.365450</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row2_col3" class="data row2 col3" >0.896400</td>
#             </tr>
#             <tr>
#                         <th id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002level0_row3" class="row_heading level0 row3" >2_relu_128_adam_3_model</th>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row3_col0" class="data row3 col0" >0.139479</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row3_col1" class="data row3 col1" >0.945033</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row3_col2" class="data row3 col2" >0.345708</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row3_col3" class="data row3 col3" >0.896100</td>
#             </tr>
#             <tr>
#                         <th id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002level0_row4" class="row_heading level0 row4" >1_relu_256_adam_4_model</th>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row4_col0" class="data row4 col0" >0.151510</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row4_col1" class="data row4 col1" >0.942267</td>
#                         <td id="T_9bade3dc_5112_11eb_b6a5_0242ac1c0002row4_col2" class="data row4 col2" >0.337883</td>
#                         <td id="T_9bade3dc_5112

# %% [markdown]
# Similarly to the training results, when sorted by test scores, all the top 10 models were trained with the `adam` optimizer, and there is no `full-batch` models.
#
# Given that the score values are all so close, let's look at how each individual modifier influenced the model results.

# %%
modifiers = neuron_multipliers + activations + batch_sizes + optimizers

# %%
modifier_scores = {modifier: scores_df.filter(like=str(modifier), axis=0).mean() for modifier in modifiers}

# %%
modifier_scores_df = pd.DataFrame.from_dict(modifier_scores, orient='index')
modifier_scores_df.sort_values(by=['val_accuracy', 'accuracy'], ascending=False, inplace=True)

# %%
modifier_scores_df.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_5866527e_5114_11eb_b6a5_0242ac1c0002row0_col0,#T_5866527e_5114_11eb_b6a5_0242ac1c0002row0_col2,#T_5866527e_5114_11eb_b6a5_0242ac1c0002row10_col1,#T_5866527e_5114_11eb_b6a5_0242ac1c0002row10_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row0_col1,#T_5866527e_5114_11eb_b6a5_0242ac1c0002row0_col3,#T_5866527e_5114_11eb_b6a5_0242ac1c0002row10_col0,#T_5866527e_5114_11eb_b6a5_0242ac1c0002row10_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row1_col0{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row1_col1{
#             background-color:  #023b5d;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row1_col2{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row1_col3{
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row2_col0{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row2_col1{
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row2_col2{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row2_col3{
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row3_col0{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row3_col1{
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row3_col2{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row3_col3{
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row4_col0{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row4_col1,#T_5866527e_5114_11eb_b6a5_0242ac1c0002row4_col3{
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row4_col2{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row5_col0{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row5_col1,#T_5866527e_5114_11eb_b6a5_0242ac1c0002row5_col3{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row5_col2{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row6_col0{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row6_col1{
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row6_col2{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row6_col3{
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row7_col0{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row7_col1{
#             background-color:  #167bb6;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row7_col2{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row7_col3,#T_5866527e_5114_11eb_b6a5_0242ac1c0002row8_col3{
#             background-color:  #187cb6;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row8_col0{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row8_col1{
#             background-color:  #157ab5;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row8_col2{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row9_col0{
#             background-color:  #7dacd1;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row9_col1{
#             background-color:  #65a3cb;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row9_col2{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_5866527e_5114_11eb_b6a5_0242ac1c0002row9_col3{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }</style><table id="T_5866527e_5114_11eb_b6a5_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >loss</th>        <th class="col_heading level0 col1" >accuracy</th>        <th class="col_heading level0 col2" >val_loss</th>        <th class="col_heading level0 col3" >val_accuracy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5866527e_5114_11eb_b6a5_0242ac1c0002level0_row0" class="row_heading level0 row0" >64</th>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row0_col0" class="data row0 col0" >0.241947</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row0_col1" class="data row0 col1" >0.911098</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row0_col2" class="data row0 col2" >0.365050</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row0_col3" class="data row0 col3" >0.877142</td>
#             </tr>
#             <tr>
#                         <th id="T_5866527e_5114_11eb_b6a5_0242ac1c0002level0_row1" class="row_heading level0 row1" >128</th>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row1_col0" class="data row1 col0" >0.254399</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row1_col1" class="data row1 col1" >0.907469</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row1_col2" class="data row1 col2" >0.372140</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row1_col3" class="data row1 col3" >0.874394</td>
#             </tr>
#             <tr>
#                         <th id="T_5866527e_5114_11eb_b6a5_0242ac1c0002level0_row2" class="row_heading level0 row2" >256</th>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row2_col0" class="data row2 col0" >0.273608</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row2_col1" class="data row2 col1" >0.901954</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row2_col2" class="data row2 col2" >0.390900</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row2_col3" class="data row2 col3" >0.867081</td>
#             </tr>
#             <tr>
#                         <th id="T_5866527e_5114_11eb_b6a5_0242ac1c0002level0_row3" class="row_heading level0 row3" >adam</th>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row3_col0" class="data row3 col0" >0.284415</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row3_col1" class="data row3 col1" >0.896953</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row3_col2" class="data row3 col2" >0.423160</td>
#                         <td id="T_5866527e_5114_11eb_b6a5_0242ac1c0002row3_col3" class="data row3 col3" >0.860319</td>
#             </tr>
#             <tr>
#                         <th id="T_5866527e_5114_11eb_b6a5_0242ac1c0002level0_row4" class="row_heading level0 row4

# %% [markdown]
# As we can see here, using a `full_batch` batch size greatly reduces the accuracies and increases the loss of the models, while other batch sizes seem to be comparable. Therefore it would be my suggestion to use a batch size of 128 or 256, so computation speed is faster as lower batch sizes don't increase the results substantially.
#
# As for optimizers, `adam` is the clear winner here over `sgd`. However, these were all default values. Further parameter optimization is needed, such as adjusting learning rate and momentum for `sgd` to truly tailor the model. But for our adhoc purposes, `adam` is my suggestion.
#
# For the neuron multiplier, that increases/decreases the number of nodes per layer, shows that more nodes per layer results in a slightly better outcome than fewer nodes, with clear diminishing returns on higher node values. Using a multiplier of 2 or 1 is ideal.
#
# As for the activation function, both `relu` and `tanh` performed similiarly. Strangely, the table shows a higher mean value for `tanh` but mostly all the top 10 models in the previous tables had `relu` as the activation parameter. IT would seem that both methods are exceptable for this dataset.
